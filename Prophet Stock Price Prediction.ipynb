# %% [markdown]
# # Prophet Stock Price Prediction
#
# This information contained on this notebook and the resources avaiable for dowload through this website is not intended as, and shall not be understood or contruced as, financial advice!I developed this tool mainly to gain more experience in time series analysis and object-oriented programming. I will occasionally update this project by adding more fuctions.

# %%
from metaprodictor import Prodictor

ticker = 'spy' #Type stock Ticker that is avaiable in yahoo fiannce where is the data source for this tool
days = 365 # priddiction days, 
test_ticker = Prodictor(ticker) #analyzing data from 1/1/2010 to the most recent closing day.

# %%
#predicting the stock price for the upcoming 365 days
test_ticker.predict(days)

# %%
#Analyzing trend
test_ticker.trend_analizer(days)

# %%
# using Corranalyzer to see daily return correlation of each stocks
from metaprodictor import Corranalyzer

ticker_group = ['DVN','CLR','MRO','FANG','CVE','TRGP','SSL','EOG','COP','IMO']
highlight = 0.78

b = Corranalyzer(ticker_group)
b.matrixCorrl(highlight)
# Out:
# <style  type="text/css" >
# #T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col1,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col2,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col7,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col8,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col0,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col2,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col0,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col1,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col8,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row7_col0,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row7_col8,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row8_col0,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row8_col2,#T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row8_col7{
#             background-color :  orange;
#         }</style><table id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58" ><thead>    <tr>        <th class="index_name level0" >Symbols</th>        <th class="col_heading level0 col0" >DVN</th>        <th class="col_heading level0 col1" >CLR</th>        <th class="col_heading level0 col2" >MRO</th>        <th class="col_heading level0 col3" >FANG</th>        <th class="col_heading level0 col4" >CVE</th>        <th class="col_heading level0 col5" >TRGP</th>        <th class="col_heading level0 col6" >SSL</th>        <th class="col_heading level0 col7" >EOG</th>        <th class="col_heading level0 col8" >COP</th>        <th class="col_heading level0 col9" >IMO</th>    </tr>    <tr>        <th class="index_name level0" >Symbols</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58level0_row0" class="row_heading level0 row0" >DVN</th>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col1" class="data row0 col1" >0.792817</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col2" class="data row0 col2" >0.822154</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col3" class="data row0 col3" >0.759585</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col4" class="data row0 col4" >0.733287</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col5" class="data row0 col5" >0.661205</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col6" class="data row0 col6" >0.572582</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col7" class="data row0 col7" >0.784075</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col8" class="data row0 col8" >0.795220</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row0_col9" class="data row0 col9" >0.694877</td>
#             </tr>
#             <tr>
#                         <th id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58level0_row1" class="row_heading level0 row1" >CLR</th>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col0" class="data row1 col0" >0.792817</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col2" class="data row1 col2" >0.799061</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col3" class="data row1 col3" >0.749179</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col4" class="data row1 col4" >0.711185</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col5" class="data row1 col5" >0.634357</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col6" class="data row1 col6" >0.547938</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col7" class="data row1 col7" >0.776531</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col8" class="data row1 col8" >0.738535</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row1_col9" class="data row1 col9" >0.645017</td>
#             </tr>
#             <tr>
#                         <th id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58level0_row2" class="row_heading level0 row2" >MRO</th>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col0" class="data row2 col0" >0.822154</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col1" class="data row2 col1" >0.799061</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col3" class="data row2 col3" >0.726218</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col4" class="data row2 col4" >0.717963</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col5" class="data row2 col5" >0.633296</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col6" class="data row2 col6" >0.567575</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col7" class="data row2 col7" >0.759368</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col8" class="data row2 col8" >0.784443</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row2_col9" class="data row2 col9" >0.654773</td>
#             </tr>
#             <tr>
#                         <th id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58level0_row3" class="row_heading level0 row3" >FANG</th>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col0" class="data row3 col0" >0.759585</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col1" class="data row3 col1" >0.749179</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col2" class="data row3 col2" >0.726218</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col4" class="data row3 col4" >0.681643</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col5" class="data row3 col5" >0.599153</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col6" class="data row3 col6" >0.524233</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col7" class="data row3 col7" >0.775935</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col8" class="data row3 col8" >0.724121</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row3_col9" class="data row3 col9" >0.651785</td>
#             </tr>
#             <tr>
#                         <th id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58level0_row4" class="row_heading level0 row4" >CVE</th>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row4_col0" class="data row4 col0" >0.733287</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row4_col1" class="data row4 col1" >0.711185</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row4_col2" class="data row4 col2" >0.717963</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row4_col3" class="data row4 col3" >0.681643</td>
#                         <td id="T_08dae4e8_530a_11ec_a434_04d9f5ba7d58row4_col4" class="data row4 col4" >1.000000</td>
#                         <
